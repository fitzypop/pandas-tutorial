# %%
import pandas as pd

# %%
# data = pd.read_csv('data/survey_results_public.csv')
# use this to assign the index column
data = pd.read_csv('data/survey_results_public.csv', index_col='Respondent')
schema = pd.read_csv('data/survey_results_schema.csv', index_col='Column')
pd.set_option('display.max_columns', 70)
pd.set_option('display.max_rows', 70)
data.head(20)
# data.tail() # shows the last 5 rows
# Out:
#                                         NEWSOSites  \
# Respondent
# 1            Stack Overflow (public Q&A for anyone who codes)
# 2           Stack Overflow (public Q&A for anyone who code...
# 3            Stack Overflow (public Q&A for anyone who codes)
# 4           Stack Overflow (public Q&A for anyone who code...
# 5           Stack Overflow (public Q&A for anyone who code...
# 6           Stack Overflow (public Q&A for anyone who code...
# 7            Stack Overflow (public Q&A for anyone who codes)
# 8           Stack Overflow (public Q&A for anyone who code...
# 9           Stack Overflow (public Q&A for anyone who code...
# 10          Stack Overflow (public Q&A for anyone who code...
# 11          Stack Overflow (public Q&A for anyone who code...
# 12          Stack Overflow (public Q&A for anyone who code...
# 13          Stack Overflow (public Q&A for anyone who code...
# 14          Stack Overflow (public Q&A for anyone who code...
# ...

# %%
data.shape # tuple of (rows, columns)
# Out:
# (64461, 60)

# %%
data.info() # prints detailed info about DataFrame
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 64461 entries, 1 to 65112
# Data columns (total 60 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   MainBranch                    64162 non-null  object
#  1   Hobbyist                      64416 non-null  object
#  2   Age                           45446 non-null  float64
#  3   Age1stCode                    57900 non-null  object
#  4   CompFreq                      40069 non-null  object
#  5   CompTotal                     34826 non-null  float64
#  6   ConvertedComp                 34756 non-null  float64
#  7   Country                       64072 non-null  object
#  8   CurrencyDesc                  45472 non-null  object
#  9   CurrencySymbol                45472 non-null  object
#  10  DatabaseDesireNextYear        44070 non-null  object
#  11  DatabaseWorkedWith            49537 non-null  object
# ...

# %%
schema # the last expression in a cell will get printed
# Out:
#                                                                    QuestionText
# Column
# Respondent                    Randomized respondent ID number (not in order ...
# MainBranch                    Which of the following options best describes ...
# Hobbyist                                                Do you code as a hobby?
# Age                           What is your age (in years)? If you prefer not...
# Age1stCode                    At what age did you write your first line of c...
# CompFreq                       Is that compensation weekly, monthly, or yearly?
# CompTotal                     What is your current total compensation (salar...
# ConvertedComp                 Salary converted to annual USD salaries using ...
# Country                                                      Where do you live?
# CurrencyDesc                  Which currency do you use day-to-day? If your ...
# CurrencySymbol                Which currency do you use day-to-day? If your ...
# ...

# %%
# What's the values in MainBranch
data['MainBranch'].value_counts(dropna=False)
# Out:
# I am a developer by profession                                                   47193
# I am a student who is learning to code                                            7970
# I am not primarily a developer, but I write code sometimes as part of my work     5502
# I code primarily as a hobby                                                       2314
# I used to be a developer by profession, but no longer am                          1183
# NaN                                                                                299
# Name: MainBranch, dtype: int64

# %%
# What's the stats on Operating Systems
data['OpSys'].value_counts(normalize=True)
# Looks like Windows has almost half of the market share for developers
# With Linux barely beating MacOS for second place
# Out:
# Windows        0.483211
# Linux-based    0.265562
# MacOS          0.250320
# BSD            0.000907
# Name: OpSys, dtype: float64

# %%
count = data['Hobbyist'].value_counts()
percent = data['Hobbyist'].value_counts(normalize=True)
percentStr = data['Hobbyist'].value_counts(normalize=True).mul(100).round(1).astype(str) + '%'
pd.DataFrame({'counts': count, 'per': percent, 'per %': percentStr})
# Out:
#      counts       per  per %
# Yes   50388  0.782228  78.2%
# No    14028  0.217772  21.8%

# %%
data.loc[1:5, 'Hobbyist']
data.loc[1:5, 'Hobbyist':'Employment']
# Out:
#            Hobbyist   Age Age1stCode CompFreq  CompTotal  ConvertedComp  \
# Respondent
# 1               Yes   NaN         13  Monthly        NaN            NaN
# 2                No   NaN         19      NaN        NaN            NaN
# 3               Yes   NaN         15      NaN        NaN            NaN
# 4               Yes  25.0         18      NaN        NaN            NaN
# 5               Yes  31.0         16      NaN        NaN            NaN
#
#                        Country    CurrencyDesc CurrencySymbol  \
# Respondent
# 1                      Germany   European Euro            EUR
# 2               United Kingdom  Pound sterling            GBP
# 3           Russian Federation             NaN            NaN
# 4                      Albania    Albanian lek            ALL
# 5                United States             NaN            NaN
#
#            DatabaseDesireNextYear                         DatabaseWorkedWith  \
# Respondent
# ...

# %%
schema.loc['Hobbyist']
# Out:
# QuestionText    Do you code as a hobby?
# Name: Hobbyist, dtype: object

# %%
schema.sort_index(inplace=True)
schema
# Out:
#                                                                    QuestionText
# Column
# Age                           What is your age (in years)? If you prefer not...
# Age1stCode                    At what age did you write your first line of c...
# CompFreq                       Is that compensation weekly, monthly, or yearly?
# CompTotal                     What is your current total compensation (salar...
# ConvertedComp                 Salary converted to annual USD salaries using ...
# Country                                                      Where do you live?
# CurrencyDesc                  Which currency do you use day-to-day? If your ...
# CurrencySymbol                Which currency do you use day-to-day? If your ...
# DatabaseDesireNextYear        Which database environments have you done exte...
# DatabaseWorkedWith            Which database environments have you done exte...
# DevType                       Which of the following describe you? Please se...
# ...

# %%
# Let's find the highest paying languages
high_salary = (data['ConvertedComp'] > 70_000)
data.loc[high_salary,['Country', 'LanguageWorkedWith', 'ConvertedComp']].sort_values(by='ConvertedComp', ascending=False)
# Out:
#                   Country                                 LanguageWorkedWith  \
# Respondent
# 32406       United States             C#;HTML/CSS;JavaScript;Python;Ruby;SQL
# 45362       United States                                                NaN
# 45352       United States         Bash/Shell/PowerShell;C#;JavaScript;Python
# 1022        United States      HTML/CSS;Java;JavaScript;Scala;SQL;TypeScript
# 53449       United States  Bash/Shell/PowerShell;HTML/CSS;Java;JavaScript...
# ...                   ...                                                ...
# 15326         Netherlands                                  JavaScript;Python
# 42287              Israel                   HTML/CSS;JavaScript;PHP;Ruby;SQL
# 44018             Bahrain  Bash/Shell/PowerShell;C;C#;C++;HTML/CSS;JavaSc...
# 5459            Australia                                      C#;JavaScript
# 58883       United States                      C#;Java;JavaScript;Python;SQL
#
#             ConvertedComp
# ...

# %%
# Get a list of countries
countries = ['United States', 'India', 'United Kingdom', 'Germany', 'Canada']
data.loc[data['Country'].isin(countries), 'Country'].value_counts()
# Out:
# United States     12469
# India              8403
# United Kingdom     3896
# Germany            3890
# Canada             2191
# Name: Country, dtype: int64

# %%
# How many Respondents know python
py_filter = data['LanguageWorkedWith'].str.contains('Python', na=False)
data.loc[py_filter, 'LanguageWorkedWith']
# Out:
# Respondent
# 3                                 Objective-C;Python;Swift
# 8                                               Python;SQL
# 10                     HTML/CSS;Java;JavaScript;Python;SQL
# 13                                     C;JavaScript;Python
# 15        Bash/Shell/PowerShell;C;HTML/CSS;Java;Python;SQL
#                                ...
# 61561    Bash/Shell/PowerShell;HTML/CSS;JavaScript;Perl...
# 62391       C++;HTML/CSS;JavaScript;Python;Ruby;TypeScript
# 63077              C++;HTML/CSS;Java;JavaScript;Python;SQL
# 63640    Bash/Shell/PowerShell;C;C#;C++;HTML/CSS;Java;J...
# 64867    Assembly;Bash/Shell/PowerShell;C;C#;C++;Dart;G...
# Name: LanguageWorkedWith, Length: 25287, dtype: object

# %%
# Rename ConvertedComp to SalaryUSD
data.rename(columns={'ConvertedComp': 'SalaryUSD'}, inplace=True)
data
# Out:
#                                                      NaN
# 5                                             Java;Ruby;Scala
# ...                                                       ...
# 64858                                                     NaN
# 64867       Assembly;Bash/Shell/PowerShell;C;C#;C++;Dart;G...
# 64898                                                     NaN
# 64925                                HTML/CSS;Java;JavaScript
# 65112                         C#;HTML/CSS;Java;JavaScript;SQL
#
#                                            LanguageWorkedWith  \
# Respondent
# 1                                      C#;HTML/CSS;JavaScript
# 2                                            JavaScript;Swift
# 3                                    Objective-C;Python;Swift
# 4                                                         NaN
# 5                                           HTML/CSS;Ruby;SQL
# ...                                                       ...
# ...

# %%
data['Hobbyist'] = data['Hobbyist'].replace({"Yes": True, "No": False})
# data['Hobbyist'].value_counts()
data
# Out:
#                                                      NaN
# 5                                             Java;Ruby;Scala
# ...                                                       ...
# 64858                                                     NaN
# 64867       Assembly;Bash/Shell/PowerShell;C;C#;C++;Dart;G...
# 64898                                                     NaN
# 64925                                HTML/CSS;Java;JavaScript
# 65112                         C#;HTML/CSS;Java;JavaScript;SQL
#
#                                            LanguageWorkedWith  \
# Respondent
# 1                                      C#;HTML/CSS;JavaScript
# 2                                            JavaScript;Swift
# 3                                    Objective-C;Python;Swift
# 4                                                         NaN
# 5                                           HTML/CSS;Ruby;SQL
# ...                                                       ...
# ...
